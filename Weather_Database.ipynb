# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
OUTPUT_DATA_FILE = "WeatherPy_Database.csv"

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 724

# %%
#Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=82b2a87027ec60617e3b93e48b573a21

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
 # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Decription": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 1 | shenjiamen
# Processing Record 3 of Set 1 | santo domingo
# Processing Record 4 of Set 1 | saint boswells
# Processing Record 5 of Set 1 | honiara
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | visby
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | cariati
# Processing Record 12 of Set 1 | bathsheba
# Processing Record 13 of Set 1 | qui nhon
# Processing Record 14 of Set 1 | varnavino
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | healesville
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | hovd
# Processing Record 19 of Set 1 | payo
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | gizo
# Processing Record 23 of Set 1 | kodiak
# Processing Record 24 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | gobabis
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | samus
# Processing Record 29 of Set 1 | kavieng
# Processing Record 30 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 1 | beringovskiy
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | xichang
# Processing Record 34 of Set 1 | tiksi
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | geraldton
# Processing Record 38 of Set 1 | kruisfontein
# Processing Record 39 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 1 | katsuura
# Processing Record 41 of Set 1 | sattahip
# Processing Record 42 of Set 1 | ostrovnoy
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | waitati
# Processing Record 46 of Set 1 | pacific grove
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | kaitangata
# Processing Record 1 of Set 2 | chapleau
# Processing Record 2 of Set 2 | marawi
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 2 | emerald
# Processing Record 7 of Set 2 | suez
# Processing Record 8 of Set 2 | victoria
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | solone
# Processing Record 12 of Set 2 | little current
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | cidreira
# Processing Record 15 of Set 2 | los llanos de aridane
# Processing Record 16 of Set 2 | bluff
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | kaeo
# Processing Record 19 of Set 2 | lixourion
# Processing Record 20 of Set 2 | port elizabeth
# Processing Record 21 of Set 2 | benguela
# Processing Record 22 of Set 2 | nuuk
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | phu ly
# Processing Record 25 of Set 2 | dzhalil
# Processing Record 26 of Set 2 | severo-kurilsk
# Processing Record 27 of Set 2 | ilulissat
# Processing Record 28 of Set 2 | debre tabor
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | pergamino
# Processing Record 31 of Set 2 | bambous virieux
# Processing Record 32 of Set 2 | nouadhibou
# Processing Record 33 of Set 2 | georgetown
# Processing Record 34 of Set 2 | mayo
# Processing Record 35 of Set 2 | dikson
# Processing Record 36 of Set 2 | longyearbyen
# Processing Record 37 of Set 2 | darab
# Processing Record 38 of Set 2 | tura
# Processing Record 39 of Set 2 | cape town
# Processing Record 40 of Set 2 | gemena
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | san patricio
# Processing Record 43 of Set 2 | ixtapa
# Processing Record 44 of Set 2 | torbay
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | anchorage
# Processing Record 49 of Set 2 | itarema
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | jonesboro
# Processing Record 2 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 3 | hilo
# Processing Record 4 of Set 3 | nueva guinea
# Processing Record 5 of Set 3 | kamenka
# Processing Record 6 of Set 3 | bolshaya irba
# City not found. Skipping...
# Processing Record 7 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 3 | pangnirtung
# Processing Record 10 of Set 3 | kangaatsiaq
# Processing Record 11 of Set 3 | peniche
# Processing Record 12 of Set 3 | ternate
# Processing Record 13 of Set 3 | gravdal
# Processing Record 14 of Set 3 | dingle
# Processing Record 15 of Set 3 | nikolskoye
# Processing Record 16 of Set 3 | kudahuvadhoo
# Processing Record 17 of Set 3 | iserlohn
# Processing Record 18 of Set 3 | marzuq
# Processing Record 19 of Set 3 | burriana
# Processing Record 20 of Set 3 | hasaki
# Processing Record 21 of Set 3 | alagir
# Processing Record 22 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 3 | arraial do cabo
# Processing Record 24 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 3 | letka
# Processing Record 26 of Set 3 | ancud
# Processing Record 27 of Set 3 | sovetskiy
# Processing Record 28 of Set 3 | provideniya
# Processing Record 29 of Set 3 | darlawn
# Processing Record 30 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 3 | bend
# Processing Record 32 of Set 3 | port lincoln
# Processing Record 33 of Set 3 | san quintin
# Processing Record 34 of Set 3 | polson
# Processing Record 35 of Set 3 | khatanga
# Processing Record 36 of Set 3 | hobart
# Processing Record 37 of Set 3 | manaus
# Processing Record 38 of Set 3 | cabo san lucas
# Processing Record 39 of Set 3 | tromso
# Processing Record 40 of Set 3 | plettenberg bay
# Processing Record 41 of Set 3 | orissaare
# Processing Record 42 of Set 3 | awjilah
# Processing Record 43 of Set 3 | sonoita
# Processing Record 44 of Set 3 | touros
# Processing Record 45 of Set 3 | puerto el triunfo
# Processing Record 46 of Set 3 | warmbad
# Processing Record 47 of Set 3 | gorontalo
# Processing Record 48 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 3 | castro
# Processing Record 50 of Set 3 | roebourne
# Processing Record 1 of Set 4 | whitehorse
# Processing Record 2 of Set 4 | rocha
# Processing Record 3 of Set 4 | belmonte
# Processing Record 4 of Set 4 | tessalit
# Processing Record 5 of Set 4 | hervey bay
# Processing Record 6 of Set 4 | san diego de la union
# Processing Record 7 of Set 4 | tateyama
# Processing Record 8 of Set 4 | santiago
# Processing Record 9 of Set 4 | poum
# Processing Record 10 of Set 4 | hof
# Processing Record 11 of Set 4 | komsomolskiy
# Processing Record 12 of Set 4 | clyde river
# Processing Record 13 of Set 4 | meadow lake
# Processing Record 14 of Set 4 | nandu
# Processing Record 15 of Set 4 | saldanha
# Processing Record 16 of Set 4 | folldal
# Processing Record 17 of Set 4 | meulaboh
# Processing Record 18 of Set 4 | winslow
# Processing Record 19 of Set 4 | egvekinot
# Processing Record 20 of Set 4 | deputatskiy
# Processing Record 21 of Set 4 | srivardhan
# Processing Record 22 of Set 4 | okakarara
# Processing Record 23 of Set 4 | vardo
# Processing Record 24 of Set 4 | sangar
# Processing Record 25 of Set 4 | rupert
# Processing Record 26 of Set 4 | alofi
# Processing Record 27 of Set 4 | vila franca do campo
# Processing Record 28 of Set 4 | seymchan
# Processing Record 29 of Set 4 | rio grande
# Processing Record 30 of Set 4 | lata
# Processing Record 31 of Set 4 | burns lake
# Processing Record 32 of Set 4 | coihaique
# Processing Record 33 of Set 4 | banda aceh
# Processing Record 34 of Set 4 | takoradi
# Processing Record 35 of Set 4 | tuy hoa
# Processing Record 36 of Set 4 | gimli
# Processing Record 37 of Set 4 | husavik
# Processing Record 38 of Set 4 | batagay-alyta
# Processing Record 39 of Set 4 | kampong cham
# Processing Record 40 of Set 4 | berlevag
# Processing Record 41 of Set 4 | chuy
# Processing Record 42 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 43 of Set 4 | aginskoye
# Processing Record 44 of Set 4 | lincoln
# Processing Record 45 of Set 4 | udachnyy
# Processing Record 46 of Set 4 | krasnoarmeyskoye
# Processing Record 47 of Set 4 | zhanaozen
# Processing Record 48 of Set 4 | norman wells
# Processing Record 49 of Set 4 | awbari
# Processing Record 50 of Set 4 | sao miguel do araguaia
# Processing Record 1 of Set 5 | mahebourg
# Processing Record 2 of Set 5 | mar del plata
# Processing Record 3 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 5 | sao joao da barra
# Processing Record 5 of Set 5 | kapuskasing
# Processing Record 6 of Set 5 | kattivakkam
# Processing Record 7 of Set 5 | banepa
# Processing Record 8 of Set 5 | luanda
# Processing Record 9 of Set 5 | katangli
# Processing Record 10 of Set 5 | matamoros
# Processing Record 11 of Set 5 | ilula
# Processing Record 12 of Set 5 | fare
# Processing Record 13 of Set 5 | kampene
# Processing Record 14 of Set 5 | upernavik
# Processing Record 15 of Set 5 | grand gaube
# Processing Record 16 of Set 5 | te anau
# Processing Record 17 of Set 5 | male
# Processing Record 18 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 5 | oda
# Processing Record 20 of Set 5 | esperance
# Processing Record 21 of Set 5 | broome
# Processing Record 22 of Set 5 | san cristobal
# Processing Record 23 of Set 5 | new norfolk
# Processing Record 24 of Set 5 | great bend
# Processing Record 25 of Set 5 | gedo
# Processing Record 26 of Set 5 | aras
# Processing Record 27 of Set 5 | grindavik
# Processing Record 28 of Set 5 | coquimbo
# Processing Record 29 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 5 | bandarbeyla
# Processing Record 31 of Set 5 | tibati
# Processing Record 32 of Set 5 | faya
# Processing Record 33 of Set 5 | cao bang
# Processing Record 34 of Set 5 | airai
# Processing Record 35 of Set 5 | celestun
# Processing Record 36 of Set 5 | leningradskiy
# Processing Record 37 of Set 5 | ewa beach
# Processing Record 38 of Set 5 | yulara
# Processing Record 39 of Set 5 | port augusta
# Processing Record 40 of Set 5 | namatanai
# Processing Record 41 of Set 5 | rayong
# Processing Record 42 of Set 5 | ambulu
# Processing Record 43 of Set 5 | chesley
# Processing Record 44 of Set 5 | dudinka
# Processing Record 45 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 46 of Set 5 | kasongo-lunda
# Processing Record 47 of Set 5 | ahipara
# Processing Record 48 of Set 5 | bengkulu
# Processing Record 49 of Set 5 | constitucion
# Processing Record 50 of Set 5 | sitka
# Processing Record 1 of Set 6 | ponta do sol
# Processing Record 2 of Set 6 | caceres
# Processing Record 3 of Set 6 | krasnomayskiy
# Processing Record 4 of Set 6 | nagarote
# Processing Record 5 of Set 6 | soyo
# Processing Record 6 of Set 6 | kui buri
# Processing Record 7 of Set 6 | baykit
# Processing Record 8 of Set 6 | lavrentiya
# Processing Record 9 of Set 6 | namibe
# Processing Record 10 of Set 6 | carnarvon
# Processing Record 11 of Set 6 | niamey
# Processing Record 12 of Set 6 | tomatlan
# Processing Record 13 of Set 6 | east london
# Processing Record 14 of Set 6 | vanavara
# Processing Record 15 of Set 6 | majene
# Processing Record 16 of Set 6 | la ciotat
# Processing Record 17 of Set 6 | fortuna
# Processing Record 18 of Set 6 | iqaluit
# Processing Record 19 of Set 6 | saskylakh
# Processing Record 20 of Set 6 | lorengau
# Processing Record 21 of Set 6 | college
# Processing Record 22 of Set 6 | mackay
# Processing Record 23 of Set 6 | daud khel
# Processing Record 24 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 6 | champerico
# Processing Record 26 of Set 6 | cochabamba
# Processing Record 27 of Set 6 | wanaka
# Processing Record 28 of Set 6 | tabuk
# Processing Record 29 of Set 6 | las cruces
# Processing Record 30 of Set 6 | ayr
# Processing Record 31 of Set 6 | jacksonville
# Processing Record 32 of Set 6 | bollnas
# Processing Record 33 of Set 6 | cangucu
# Processing Record 34 of Set 6 | charters towers
# Processing Record 35 of Set 6 | aykhal
# Processing Record 36 of Set 6 | soe
# Processing Record 37 of Set 6 | camana
# Processing Record 38 of Set 6 | berberati
# Processing Record 39 of Set 6 | waounde
# Processing Record 40 of Set 6 | great malvern
# Processing Record 41 of Set 6 | madison heights
# Processing Record 42 of Set 6 | pevek
# Processing Record 43 of Set 6 | sambava
# Processing Record 44 of Set 6 | panaba
# Processing Record 45 of Set 6 | nanortalik
# Processing Record 46 of Set 6 | zafarwal
# Processing Record 47 of Set 6 | torata
# Processing Record 48 of Set 6 | narsaq
# Processing Record 49 of Set 6 | codrington
# Processing Record 50 of Set 6 | beloha
# Processing Record 1 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 7 | charlestown
# Processing Record 3 of Set 7 | swan hill
# Processing Record 4 of Set 7 | dodola
# Processing Record 5 of Set 7 | denizli
# Processing Record 6 of Set 7 | buchanan
# Processing Record 7 of Set 7 | roma
# Processing Record 8 of Set 7 | saint anthony
# Processing Record 9 of Set 7 | nome
# Processing Record 10 of Set 7 | ukiah
# Processing Record 11 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 12 of Set 7 | port shepstone
# Processing Record 13 of Set 7 | lompoc
# Processing Record 14 of Set 7 | tougue
# Processing Record 15 of Set 7 | wallaceburg
# Processing Record 16 of Set 7 | kurilsk
# Processing Record 17 of Set 7 | klaksvik
# Processing Record 18 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 7 | fontenay-le-comte
# Processing Record 20 of Set 7 | shebalino
# Processing Record 21 of Set 7 | puksoozero
# Processing Record 22 of Set 7 | fairbanks
# Processing Record 23 of Set 7 | bahia blanca
# Processing Record 24 of Set 7 | san carlos
# Processing Record 25 of Set 7 | challapata
# Processing Record 26 of Set 7 | grasten
# Processing Record 27 of Set 7 | padang
# Processing Record 28 of Set 7 | faanui
# Processing Record 29 of Set 7 | coahuayana
# Processing Record 30 of Set 7 | lagoa
# Processing Record 31 of Set 7 | northam
# Processing Record 32 of Set 7 | kahului
# Processing Record 33 of Set 7 | bethel
# Processing Record 34 of Set 7 | mlonggo
# Processing Record 35 of Set 7 | beroroha
# Processing Record 36 of Set 7 | yumen
# Processing Record 37 of Set 7 | dustlik
# Processing Record 38 of Set 7 | murdochville
# Processing Record 39 of Set 7 | mae tha
# Processing Record 40 of Set 7 | huarmey
# Processing Record 41 of Set 7 | sibolga
# Processing Record 42 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 7 | mchinji
# Processing Record 44 of Set 7 | mount gambier
# Processing Record 45 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 46 of Set 7 | ust-nera
# Processing Record 47 of Set 7 | paucartambo
# City not found. Skipping...
# Processing Record 48 of Set 7 | richards bay
# Processing Record 49 of Set 7 | cabedelo
# Processing Record 50 of Set 7 | isiro
# Processing Record 1 of Set 8 | oktyabrskoye
# Processing Record 2 of Set 8 | tuatapere
# Processing Record 3 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 4 of Set 8 | kidal
# Processing Record 5 of Set 8 | talnakh
# Processing Record 6 of Set 8 | chililabombwe
# Processing Record 7 of Set 8 | foso
# Processing Record 8 of Set 8 | ambatondrazaka
# Processing Record 9 of Set 8 | sabang
# Processing Record 10 of Set 8 | bundaberg
# Processing Record 11 of Set 8 | borovskoy
# Processing Record 12 of Set 8 | goderich
# Processing Record 13 of Set 8 | epe
# Processing Record 14 of Set 8 | the valley
# Processing Record 15 of Set 8 | adrar
# Processing Record 16 of Set 8 | gamba
# Processing Record 17 of Set 8 | tibasosa
# Processing Record 18 of Set 8 | kalmunai
# Processing Record 19 of Set 8 | puerto escondido
# Processing Record 20 of Set 8 | oxford
# Processing Record 21 of Set 8 | hofn
# Processing Record 22 of Set 8 | isetskoye
# Processing Record 23 of Set 8 | matara
# Processing Record 24 of Set 8 | cherskiy
# Processing Record 25 of Set 8 | araouane
# Processing Record 26 of Set 8 | vestmannaeyjar
# Processing Record 27 of Set 8 | bhongir
# Processing Record 28 of Set 8 | yarmouth
# Processing Record 29 of Set 8 | jiblah
# Processing Record 30 of Set 8 | coos bay
# Processing Record 31 of Set 8 | lusambo
# Processing Record 32 of Set 8 | douglas
# Processing Record 33 of Set 8 | gornyy
# Processing Record 34 of Set 8 | sola
# Processing Record 35 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 8 | tahoua
# Processing Record 37 of Set 8 | nikki
# Processing Record 38 of Set 8 | achisay
# City not found. Skipping...
# Processing Record 39 of Set 8 | yartsevo
# Processing Record 40 of Set 8 | bodden town
# Processing Record 41 of Set 8 | moron
# Processing Record 42 of Set 8 | guerrero negro
# Processing Record 43 of Set 8 | wajid
# Processing Record 44 of Set 8 | vigrestad
# Processing Record 45 of Set 8 | rundu
# Processing Record 46 of Set 8 | szabadbattyan
# Processing Record 47 of Set 8 | kilrush
# Processing Record 48 of Set 8 | miramar
# Processing Record 49 of Set 8 | nago
# Processing Record 50 of Set 8 | aurad
# Processing Record 1 of Set 9 | kijang
# Processing Record 2 of Set 9 | kenora
# Processing Record 3 of Set 9 | zheleznodorozhnyy
# Processing Record 4 of Set 9 | tazovskiy
# Processing Record 5 of Set 9 | raga
# Processing Record 6 of Set 9 | chilliwack
# Processing Record 7 of Set 9 | caravelas
# Processing Record 8 of Set 9 | warrnambool
# Processing Record 9 of Set 9 | dongsheng
# Processing Record 10 of Set 9 | farah
# Processing Record 11 of Set 9 | kaseda
# Processing Record 12 of Set 9 | columbus
# Processing Record 13 of Set 9 | gwadar
# Processing Record 14 of Set 9 | hobyo
# Processing Record 15 of Set 9 | cedar city
# Processing Record 16 of Set 9 | mococa
# Processing Record 17 of Set 9 | jalu
# Processing Record 18 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 19 of Set 9 | xinmin
# Processing Record 20 of Set 9 | algiers
# Processing Record 21 of Set 9 | puerto suarez
# Processing Record 22 of Set 9 | bardiyah
# Processing Record 23 of Set 9 | srednekolymsk
# Processing Record 24 of Set 9 | kokomo
# Processing Record 25 of Set 9 | uvalde
# Processing Record 26 of Set 9 | hokitika
# Processing Record 27 of Set 9 | margate
# Processing Record 28 of Set 9 | shintomi
# Processing Record 29 of Set 9 | ornskoldsvik
# Processing Record 30 of Set 9 | kieta
# Processing Record 31 of Set 9 | mahajanga
# Processing Record 32 of Set 9 | cabra
# Processing Record 33 of Set 9 | naze
# Processing Record 34 of Set 9 | west odessa
# Processing Record 35 of Set 9 | gold coast
# Processing Record 36 of Set 9 | tahe
# Processing Record 37 of Set 9 | maniitsoq
# Processing Record 38 of Set 9 | williston
# Processing Record 39 of Set 9 | taywarah
# Processing Record 40 of Set 9 | sapa
# Processing Record 41 of Set 9 | timra
# Processing Record 42 of Set 9 | pisco
# Processing Record 43 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 44 of Set 9 | turukhansk
# Processing Record 45 of Set 9 | mae chan
# Processing Record 46 of Set 9 | vila velha
# Processing Record 47 of Set 9 | ibra
# Processing Record 48 of Set 9 | vuktyl
# Processing Record 49 of Set 9 | inirida
# Processing Record 50 of Set 9 | black river
# Processing Record 1 of Set 10 | cattolica
# Processing Record 2 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 3 of Set 10 | trairi
# Processing Record 4 of Set 10 | robore
# Processing Record 5 of Set 10 | shchigry
# Processing Record 6 of Set 10 | biak
# Processing Record 7 of Set 10 | manokwari
# Processing Record 8 of Set 10 | natal
# Processing Record 9 of Set 10 | yasnyy
# Processing Record 10 of Set 10 | westport
# Processing Record 11 of Set 10 | novyy urgal
# Processing Record 12 of Set 10 | ishigaki
# Processing Record 13 of Set 10 | tank
# Processing Record 14 of Set 10 | kloulklubed
# Processing Record 15 of Set 10 | qasigiannguit
# Processing Record 16 of Set 10 | mto wa mbu
# Processing Record 17 of Set 10 | shubarkuduk
# Processing Record 18 of Set 10 | victor harbor
# Processing Record 19 of Set 10 | potchefstroom
# Processing Record 20 of Set 10 | vanimo
# Processing Record 21 of Set 10 | cavalcante
# Processing Record 22 of Set 10 | netrakona
# Processing Record 23 of Set 10 | guadalupe y calvo
# Processing Record 24 of Set 10 | laranjeiras
# Processing Record 25 of Set 10 | palana
# Processing Record 26 of Set 10 | san marcos
# Processing Record 27 of Set 10 | zemetchino
# Processing Record 28 of Set 10 | tiszaluc
# Processing Record 29 of Set 10 | fort nelson
# Processing Record 30 of Set 10 | kolokani
# Processing Record 31 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 10 | brahmapuri
# City not found. Skipping...
# Processing Record 33 of Set 10 | flinders
# Processing Record 34 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 35 of Set 10 | gigmoto
# Processing Record 36 of Set 10 | semnan
# Processing Record 37 of Set 10 | zhigansk
# Processing Record 38 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 10 | hambantota
# Processing Record 40 of Set 10 | makakilo city
# Processing Record 41 of Set 10 | saint-louis
# Processing Record 42 of Set 10 | likasi
# Processing Record 43 of Set 10 | dunedin
# Processing Record 44 of Set 10 | donghai
# Processing Record 45 of Set 10 | berezovka
# Processing Record 46 of Set 10 | azare
# Processing Record 47 of Set 10 | tilichiki
# Processing Record 48 of Set 10 | manzhouli
# Processing Record 49 of Set 10 | wanning
# Processing Record 50 of Set 10 | bireun
# Processing Record 1 of Set 11 | asau
# Processing Record 2 of Set 11 | nhulunbuy
# Processing Record 3 of Set 11 | kisangani
# Processing Record 4 of Set 11 | ballina
# Processing Record 5 of Set 11 | monte alegre
# Processing Record 6 of Set 11 | kachiry
# Processing Record 7 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 11 | lishu
# Processing Record 9 of Set 11 | kathu
# Processing Record 10 of Set 11 | espanola
# Processing Record 11 of Set 11 | shelburne
# Processing Record 12 of Set 11 | orneta
# Processing Record 13 of Set 11 | smirnykh
# Processing Record 14 of Set 11 | ca mau
# Processing Record 15 of Set 11 | broceni
# Processing Record 16 of Set 11 | prince george
# Processing Record 17 of Set 11 | murgab
# Processing Record 18 of Set 11 | joshimath
# Processing Record 19 of Set 11 | sao felix do xingu
# Processing Record 20 of Set 11 | blackwater
# Processing Record 21 of Set 11 | suna
# Processing Record 22 of Set 11 | port hardy
# Processing Record 23 of Set 11 | timizart
# Processing Record 24 of Set 11 | mazatlan
# Processing Record 25 of Set 11 | souillac
# Processing Record 26 of Set 11 | sindand
# City not found. Skipping...
# Processing Record 27 of Set 11 | san rafael
# Processing Record 28 of Set 11 | taoudenni
# Processing Record 29 of Set 11 | vestmanna
# Processing Record 30 of Set 11 | adeje
# Processing Record 31 of Set 11 | iberia
# Processing Record 32 of Set 11 | walvis bay
# Processing Record 33 of Set 11 | malchin
# Processing Record 34 of Set 11 | puerto madryn
# Processing Record 35 of Set 11 | gouyave
# Processing Record 36 of Set 11 | bouar
# Processing Record 37 of Set 11 | morondava
# Processing Record 38 of Set 11 | praia
# Processing Record 39 of Set 11 | kalomo
# City not found. Skipping...
# Processing Record 40 of Set 11 | mogochin
# City not found. Skipping...
# Processing Record 41 of Set 11 | palmer
# Processing Record 42 of Set 11 | coyutla
# Processing Record 43 of Set 11 | windsor
# Processing Record 44 of Set 11 | valparaiso
# Processing Record 45 of Set 11 | maarianhamina
# Processing Record 46 of Set 11 | saint-leu
# Processing Record 47 of Set 11 | maningrida
# Processing Record 48 of Set 11 | killarney
# Processing Record 49 of Set 11 | smithers
# Processing Record 50 of Set 11 | vreed en hoop
# City not found. Skipping...
# Processing Record 1 of Set 12 | borogontsy
# Processing Record 2 of Set 12 | kasongo
# Processing Record 3 of Set 12 | riyadh
# Processing Record 4 of Set 12 | ojinaga
# Processing Record 5 of Set 12 | manta
# Processing Record 6 of Set 12 | jinchang
# Processing Record 7 of Set 12 | bow island
# Processing Record 8 of Set 12 | luderitz
# Processing Record 9 of Set 12 | karratha
# Processing Record 10 of Set 12 | xai-xai
# Processing Record 11 of Set 12 | viransehir
# Processing Record 12 of Set 12 | sukumo
# Processing Record 13 of Set 12 | mount isa
# Processing Record 14 of Set 12 | arica
# Processing Record 15 of Set 12 | nantucket
# Processing Record 16 of Set 12 | whitianga
# Processing Record 17 of Set 12 | vao
# Processing Record 18 of Set 12 | swabi
# Processing Record 19 of Set 12 | kavaratti
# Processing Record 20 of Set 12 | sao filipe
# Processing Record 21 of Set 12 | ketchikan
# Processing Record 22 of Set 12 | marsh harbour
# Processing Record 23 of Set 12 | fallon
# Processing Record 24 of Set 12 | portland
# Processing Record 25 of Set 12 | dipkarpaz
# City not found. Skipping...
# Processing Record 26 of Set 12 | aklavik
# Processing Record 27 of Set 12 | niquero
# Processing Record 28 of Set 12 | mitu
# Processing Record 29 of Set 12 | camocim
# Processing Record 30 of Set 12 | pihuamo
# Processing Record 31 of Set 12 | atambua
# Processing Record 32 of Set 12 | zakinthos
# City not found. Skipping...
# Processing Record 33 of Set 12 | worland
# Processing Record 34 of Set 12 | cravinhos
# Processing Record 35 of Set 12 | morgan city
# Processing Record 36 of Set 12 | livermore
# Processing Record 37 of Set 12 | yei
# Processing Record 38 of Set 12 | tete
# Processing Record 39 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 12 | vila
# Processing Record 42 of Set 12 | kabansk
# Processing Record 43 of Set 12 | novorzhev
# Processing Record 44 of Set 12 | antigonish
# Processing Record 45 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 46 of Set 12 | batagay
# Processing Record 47 of Set 12 | plakhtiyivka
# Processing Record 48 of Set 12 | dhuwaran
# Processing Record 49 of Set 12 | la esperanza
# Processing Record 50 of Set 12 | aksha
# Processing Record 1 of Set 13 | ilawa
# Processing Record 2 of Set 13 | korla
# Processing Record 3 of Set 13 | bud
# Processing Record 4 of Set 13 | nanjing
# Processing Record 5 of Set 13 | cabacao
# Processing Record 6 of Set 13 | reyes
# Processing Record 7 of Set 13 | osoyoos
# Processing Record 8 of Set 13 | olinda
# Processing Record 9 of Set 13 | jambi
# Processing Record 10 of Set 13 | kapit
# Processing Record 11 of Set 13 | moussoro
# Processing Record 12 of Set 13 | hualmay
# Processing Record 13 of Set 13 | centralia
# Processing Record 14 of Set 13 | virar
# Processing Record 15 of Set 13 | pisticci
# Processing Record 16 of Set 13 | patiala
# Processing Record 17 of Set 13 | henties bay
# Processing Record 18 of Set 13 | vredendal
# Processing Record 19 of Set 13 | hachinohe
# Processing Record 20 of Set 13 | umm lajj
# Processing Record 21 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 22 of Set 13 | ubinskoye
# Processing Record 23 of Set 13 | murchison
# Processing Record 24 of Set 13 | nurota
# Processing Record 25 of Set 13 | bairiki
# Processing Record 26 of Set 13 | camacha
# Processing Record 27 of Set 13 | angoram
# Processing Record 28 of Set 13 | ola
# Processing Record 29 of Set 13 | okha
# Processing Record 30 of Set 13 | mattru
# Processing Record 31 of Set 13 | pemangkat
# Processing Record 32 of Set 13 | orlandia
# Processing Record 33 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 34 of Set 13 | lawton
# Processing Record 35 of Set 13 | kargalinskaya
# Processing Record 36 of Set 13 | nishihara
# Processing Record 37 of Set 13 | sabzevar
# Processing Record 38 of Set 13 | avanigadda
# Processing Record 39 of Set 13 | ust-tsilma
# Processing Record 40 of Set 13 | samarai
# Processing Record 41 of Set 13 | verkhnevilyuysk
# Processing Record 42 of Set 13 | kongolo
# Processing Record 43 of Set 13 | unguia
# Processing Record 44 of Set 13 | tucuman
# Processing Record 45 of Set 13 | ghimes-faget
# Processing Record 46 of Set 13 | malanje
# Processing Record 47 of Set 13 | pauini
# Processing Record 48 of Set 13 | lucapa
# Processing Record 49 of Set 13 | savelugu
# Processing Record 50 of Set 13 | paramonga
# Processing Record 1 of Set 14 | san vicente
# Processing Record 2 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 14 | naantali
# Processing Record 4 of Set 14 | aleksandrovsk-sakhalinskiy
# Processing Record 5 of Set 14 | puntarenas
# Processing Record 6 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 7 of Set 14 | inhambane
# Processing Record 8 of Set 14 | cam ranh
# Processing Record 9 of Set 14 | chicama
# Processing Record 10 of Set 14 | ayorou
# Processing Record 11 of Set 14 | acapulco
# Processing Record 12 of Set 14 | pompeu
# Processing Record 13 of Set 14 | qitaihe
# Processing Record 14 of Set 14 | ingham
# Processing Record 15 of Set 14 | algodones
# Processing Record 16 of Set 14 | nan
# Processing Record 17 of Set 14 | verkh-usugli
# Processing Record 18 of Set 14 | poya
# Processing Record 19 of Set 14 | kindu
# Processing Record 20 of Set 14 | tautira
# Processing Record 21 of Set 14 | masallatah
# Processing Record 22 of Set 14 | van
# Processing Record 23 of Set 14 | oranjemund
# Processing Record 24 of Set 14 | novobirilyussy
# Processing Record 25 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 14 | carballo
# Processing Record 27 of Set 14 | pangai
# Processing Record 28 of Set 14 | tsabong
# Processing Record 29 of Set 14 | dekar
# Processing Record 30 of Set 14 | rosa zarate
# Processing Record 31 of Set 14 | labuan
# Processing Record 32 of Set 14 | agropoli
# Processing Record 33 of Set 14 | inongo
# Processing Record 34 of Set 14 | mogadishu
# Processing Record 35 of Set 14 | talcahuano
# Processing Record 36 of Set 14 | necochea
# Processing Record 37 of Set 14 | licheng
# Processing Record 38 of Set 14 | berdigestyakh
# Processing Record 39 of Set 14 | vostok
# Processing Record 40 of Set 14 | zhuozhou
# City not found. Skipping...
# Processing Record 41 of Set 14 | svetlaya
# Processing Record 42 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 44 of Set 14 | bukachacha
# Processing Record 45 of Set 14 | dali
# Processing Record 46 of Set 14 | tianpeng
# Processing Record 47 of Set 14 | mbaiki
# Processing Record 48 of Set 14 | garm
# City not found. Skipping...
# Processing Record 49 of Set 14 | salalah
# Processing Record 50 of Set 14 | nara
# Processing Record 1 of Set 15 | marmora
# Processing Record 2 of Set 15 | rabo de peixe
# Processing Record 3 of Set 15 | juegang
# Processing Record 4 of Set 15 | tukrah
# Processing Record 5 of Set 15 | port blair
# Processing Record 6 of Set 15 | west lafayette
# Processing Record 7 of Set 15 | khuzhir
# Processing Record 8 of Set 15 | havre-saint-pierre
# Processing Record 9 of Set 15 | saint-pierre
# Processing Record 10 of Set 15 | eyl
# Processing Record 11 of Set 15 | churapcha
# Processing Record 12 of Set 15 | laguna
# Processing Record 13 of Set 15 | macedo de cavaleiros
# Processing Record 14 of Set 15 | nelson bay
# Processing Record 15 of Set 15 | nuevitas
# Processing Record 16 of Set 15 | gazanjyk
# Processing Record 17 of Set 15 | kodinsk
# Processing Record 18 of Set 15 | trinidad
# Processing Record 19 of Set 15 | pachino
# Processing Record 20 of Set 15 | gilbues
# Processing Record 21 of Set 15 | bure
# Processing Record 22 of Set 15 | inta
# Processing Record 23 of Set 15 | dauriya
# Processing Record 24 of Set 15 | dakar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Shenjiamen  29.9576  122.2980     57.52        94          45
# 1   Santo Domingo  18.5001  -69.9886     85.68        68          75
# 2  Saint Boswells  55.5730   -2.6441     47.16        83          73
# 3         Honiara  -9.4333  159.9500     76.01        91         100
# 4     Tuktoyaktuk  69.4541 -133.0374    -14.80        76          75
# 5         Rikitea -23.1203 -134.9692     78.69        73          74
# 6           Visby  57.6409   18.2960     37.62        48          19
# 7         Ushuaia -54.8000  -68.3000     49.66        62          75
# 8          Albany  42.6001  -73.9662     27.43        92         100
# 9         Cariati  39.4922   16.9594     43.99        59          44
#
#    Wind Speed Country                 Date        Decription
# 0       20.27      CN  2022-03-12 17:32:24  scattered clouds
# 1        4.00      DO  2022-03-12 17:27:53     broken clouds
# 2        5.59      GB  2022-03-12 17:32:24     broken clouds
# 3        0.81      SB  2022-03-12 17:30:15   overcast clouds
# 4       12.66      CA  2022-03-12 17:32:25        light snow
# 5       10.07      PF  2022-03-12 17:32:25     broken clouds
# 6        4.61      SE  2022-03-12 17:28:47        few clouds
# 7        5.75      AR  2022-03-12 17:32:25     broken clouds
# 8        5.99      US  2022-03-12 17:30:14              snow
# 9        0.98      IT  2022-03-12 17:32:26  scattered clouds

# %%
#cols = city_data_df.columns.tolist()
#cols
# Reorder Columns
new_col_ord = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Decription"]
#Assign new dataframe with reordered columns
city_data_df = city_data_df[new_col_ord]
city_data_df
# Out:
#                City Country                 Date      Lat       Lng  Max Temp  \
# 0        Shenjiamen      CN  2022-03-12 17:32:24  29.9576  122.2980     57.52
# 1     Santo Domingo      DO  2022-03-12 17:27:53  18.5001  -69.9886     85.68
# 2    Saint Boswells      GB  2022-03-12 17:32:24  55.5730   -2.6441     47.16
# 3           Honiara      SB  2022-03-12 17:30:15  -9.4333  159.9500     76.01
# 4       Tuktoyaktuk      CA  2022-03-12 17:32:25  69.4541 -133.0374    -14.80
# ..              ...     ...                  ...      ...       ...       ...
# 663         Gilbues      BR  2022-03-12 17:51:36  -9.8317  -45.3439     85.15
# 664            Bure      ET  2022-03-12 17:51:36  10.7000   37.0667     66.31
# 665            Inta      RU  2022-03-12 17:51:37  66.0317   60.1659     20.79
# 666         Dauriya      RU  2022-03-12 17:51:37  49.9333  116.8667      3.47
# 667           Dakar      SN  2022-03-12 17:51:37  14.6937  -17.4441     97.68
#
#      Humidity  Cloudiness  Wind Speed        Decription
# 0          94          45       20.27  scattered clouds
# 1          68          75        4.00     broken clouds
# 2          83          73        5.59     broken clouds
# 3          91         100        0.81   overcast clouds
# 4          76          75       12.66        light snow
# ..        ...         ...         ...               ...
# 663        52          86        6.08   overcast clouds
# 664        51          99        7.05   overcast clouds
# 665        88         100       16.51   overcast clouds
# 666       100          73        0.85     broken clouds
# 667        47          22       13.80              dust
#
# [668 rows x 10 columns]

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(OUTPUT_DATA_FILE, index_label="City_ID")
# Delete Dataframe
del(city_data_df)

# %%
# Read CSV file *******
city_data_df = pd.read_csv(OUTPUT_DATA_FILE)

# %%
city_data_df
# Out:
#      City_ID  City_ID.1            City Country                 Date      Lat  \
# 0          0          0      Shenjiamen      CN  2022-03-12 17:32:24  29.9576
# 1          1          1   Santo Domingo      DO  2022-03-12 17:27:53  18.5001
# 2          2          2  Saint Boswells      GB  2022-03-12 17:32:24  55.5730
# 3          3          3         Honiara      SB  2022-03-12 17:30:15  -9.4333
# 4          4          4     Tuktoyaktuk      CA  2022-03-12 17:32:25  69.4541
# ..       ...        ...             ...     ...                  ...      ...
# 663      663        663         Gilbues      BR  2022-03-12 17:51:36  -9.8317
# 664      664        664            Bure      ET  2022-03-12 17:51:36  10.7000
# 665      665        665            Inta      RU  2022-03-12 17:51:37  66.0317
# 666      666        666         Dauriya      RU  2022-03-12 17:51:37  49.9333
# 667      667        667           Dakar      SN  2022-03-12 17:51:37  14.6937
#
#           Lng  Max Temp  Humidity  Cloudiness  Wind Speed        Decription
# 0    122.2980     57.52        94          45       20.27  scattered clouds
# 1    -69.9886     85.68        68          75        4.00     broken clouds
# 2     -2.6441     47.16        83          73        5.59     broken clouds
# 3    159.9500     76.01        91         100        0.81   overcast clouds
# 4   -133.0374    -14.80        76          75       12.66        light snow
# ..        ...       ...       ...         ...         ...               ...
# 663  -45.3439     85.15        52          86        6.08   overcast clouds
# 664   37.0667     66.31        51          99        7.05   overcast clouds
# 665   60.1659     20.79        88         100       16.51   overcast clouds
# 666  116.8667      3.47       100          73        0.85     broken clouds
# 667  -17.4441     97.68        47          22       13.80              dust
#
# [668 rows x 12 columns]
